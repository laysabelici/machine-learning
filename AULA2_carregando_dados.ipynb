# %% [markdown]
# <a href="https://colab.research.google.com/github/laysabelici/machine-learning/blob/main/AULA2_carregando_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# BIBLIOTECAS E IMPORTS

# %%
#BIBLIOTECA PARA GRÁFICOS DINAMICOS
# !pip install plotly --upgrade
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.6/15.6 MB 32.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.15.0
#     Uninstalling plotly-5.15.0:
#       Successfully uninstalled plotly-5.15.0
# ...

# %%
#BIBLIOTECA PARA CARREGAMENTO DE ARQUIVOS, DATAFRAMES
import pandas as pd

#FUNÇÕES MATEMATICAS EM GRANDE ESCALA
import numpy as np

#PARA VISUALIZAÇÕES ESTATISTICAS E INFORMATIVAS
import seaborn as sns

#PARA GRAFICOS ESTATISTICOS, INTERATIVOS E ANIMADOS
import matplotlib.pyplot as plt

#VISUALIZAÇÕES DE GRAFICOS COMPLEXOS
import plotly.express as px

# %% [markdown]
# EXPLORAÇÃO DE DADOS

# %%
base_credit = pd.read_csv('/content/credit_data.csv') #carregara base de dados

# %%
base_credit.head(5) #mostra os 5 primeiros itens da lista

#clientid: categóricas nominal
#income: numérica continua
#age: numérico continua (float)
#loan: numérico continua
#default: numérico discreto (sim ou não)
#objetivo: usar essas informações para prever ser o cliente tem tendencias a quitar emprestimo.
# Out:
#    clientid        income        age         loan  default
# 0         1  66155.925095  59.017015  8106.532131        0
# 1         2  34415.153966  48.117153  6564.745018        0
# 2         3  57317.170063  63.108049  8020.953296        0
# 3         4  42709.534201  45.751972  6103.642260        0
# 4         5  66952.688845  18.584336  8770.099235        1

# %%
base_credit.tail(5) #para ver os 5 últimos itens da lista
# Out:
#       clientid        income        age         loan  default
# 1995      1996  59221.044874  48.518179  1926.729397        0
# 1996      1997  69516.127573  23.162104  3503.176156        0
# 1997      1998  44311.449262  28.017167  5522.786693        1
# 1998      1999  43756.056605  63.971796  1622.722598        0
# 1999      2000  69436.579552  56.152617  7378.833599        0

# %%
base_credit.describe() #retorna ferramentas do pandas

#count: contagem
#mean: média
#std: desvio padrão, variação dos dados em relação a média
#min: valores minimos
#max: valores máximos
#25%:
#50%:
#75%:
# Out:
#           clientid        income          age          loan      default
# count  2000.000000   2000.000000  1997.000000   2000.000000  2000.000000
# mean   1000.500000  45331.600018    40.807559   4444.369695     0.141500
# std     577.494589  14326.327119    13.624469   3045.410024     0.348624
# min       1.000000  20014.489470   -52.423280      1.377630     0.000000
# 25%     500.750000  32796.459717    28.990415   1939.708847     0.000000
# 50%    1000.500000  45789.117313    41.317159   3974.719419     0.000000
# 75%    1500.250000  57791.281668    52.587040   6432.410625     0.000000
# max    2000.000000  69995.685578    63.971796  13766.051239     1.000000

# %%
#filtro para retornar o maior salário da base
base_credit[base_credit['income'] >= 69995.685578]
# Out:
#      clientid        income        age         loan  default
# 422       423  69995.685578  52.719673  2084.370861        0

# %%
#filtro para menor divida
base_credit[base_credit['loan'] <= 1.377630]
# Out:
#      clientid        income        age     loan  default
# 865       866  28072.604355  54.142548  1.37763        0
